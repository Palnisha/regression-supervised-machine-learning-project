# %% [markdown]
# # Project 1 - Regression supervised learning Regression :

# %% [markdown]
# Predicting Employee Salaries : Problem Statement: Predicting Employee Salaries
#
# Project Description: Build a regression model to predict employee salaries based on factors such as job title, years of experience, education level, and performance metrics. Domain: Human Resources

# %%
import numpy as np
import pandas as pd
data = pd.read_csv('Salary Data.csv')
data
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375 entries, 0 to 374
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  373 non-null    float64
#  1   Gender               373 non-null    object
#  2   Education Level      373 non-null    object
#  3   Job Title            373 non-null    object
#  4   Years of Experience  373 non-null    float64
#  5   Salary               373 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 17.7+ KB

# %%
data.isnull().sum()
# Out:
# Age                    2
# Gender                 2
# Education Level        2
# Job Title              2
# Years of Experience    2
# Salary                 2
# dtype: int64

# %%
data.dropna(inplace = True)

# %%
data.isna().sum()
# Out:
# Age                    0
# Gender                 0
# Education Level        0
# Job Title              0
# Years of Experience    0
# Salary                 0
# dtype: int64

# %%
data.describe()
# Out:
#               Age  Years of Experience         Salary
# count  373.000000           373.000000     373.000000
# mean    37.431635            10.030831  100577.345845
# std      7.069073             6.557007   48240.013482
# min     23.000000             0.000000     350.000000
# 25%     31.000000             4.000000   55000.000000
# 50%     36.000000             9.000000   95000.000000
# 75%     44.000000            15.000000  140000.000000
# max     53.000000            25.000000  250000.000000

# %%
data.head(10)
# Out:
#     Age  Gender Education Level              Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's      Software Engineer                  5.0
# 1  28.0  Female        Master's           Data Analyst                  3.0
# 2  45.0    Male             PhD         Senior Manager                 15.0
# 3  36.0  Female      Bachelor's        Sales Associate                  7.0
# 4  52.0    Male        Master's               Director                 20.0
# 5  29.0    Male      Bachelor's      Marketing Analyst                  2.0
# 6  42.0  Female        Master's        Product Manager                 12.0
# 7  31.0    Male      Bachelor's          Sales Manager                  4.0
# 8  26.0  Female      Bachelor's  Marketing Coordinator                  1.0
# 9  38.0    Male             PhD       Senior Scientist                 10.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0
# 5   55000.0
# 6  120000.0
# 7   80000.0
# ...

# %%
data.tail(10)
# Out:
#       Age  Gender Education Level                      Job Title  \
# 365  43.0    Male        Master's          Director of Marketing
# 366  31.0  Female      Bachelor's       Junior Financial Analyst
# 367  41.0    Male      Bachelor's         Senior Product Manager
# 368  44.0  Female             PhD           Senior Data Engineer
# 369  33.0    Male      Bachelor's        Junior Business Analyst
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 365                 18.0  170000.0
# 366                  3.0   50000.0
# 367                 14.0  150000.0
# 368                 16.0  160000.0
# 369                  4.0   60000.0
# ...

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Education Level', 'Job Title', 'Years of Experience',
#        'Salary'],
#       dtype='object')

# %%
####Plotting Scatter plot to check relationship between independent variable and dependent variable
import matplotlib.pyplot as plt

# %%
plt.scatter(data['Age'][:300], data["Salary"][:300])

# %%
plt.scatter(data['Years of Experience'][:300], data["Salary"][:300])

# %%
for i in data.columns[:-1]:
    plt.xlabel(i)
    plt.ylabel("Salary")
    plt.scatter(data[i][:300],data["Salary"][:300])
    plt.show()

# %%
x = np.array(data["Years of Experience"]).reshape(-1,1)
y = np.array(data["Salary"]).reshape(-1,1)

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
linear = LinearRegression()
linear.fit(x,y)
# Out:
# LinearRegression()

# %%
linear.predict([[48]])
# Out:
# array([[360457.72161228]])

# %% [markdown]
# # multiple regression

# %%
len(data.columns)
# Out:
# 6

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Education Level', 'Job Title', 'Years of Experience',
#        'Salary'],
#       dtype='object')

# %%
#### Import label encoder
from sklearn import preprocessing
  
label_encoder = preprocessing.LabelEncoder()
  
data['Gender']= label_encoder.fit_transform(data['Gender'])
  
data['Gender'].unique()
# Out:
# array([1, 0])

# %%
#### Import label encoder
from sklearn import preprocessing
  
label_encoder = preprocessing.LabelEncoder()
  
data['Education Level']= label_encoder.fit_transform(data['Education Level'])
  
data['Education Level'].unique()
# Out:
# array([0, 1, 2])

# %%
#### Import label encoder
from sklearn import preprocessing
  
label_encoder = preprocessing.LabelEncoder()
  
data['Job Title']= label_encoder.fit_transform(data['Job Title'])
  
data['Job Title'].unique()
# Out:
# array([159,  17, 130, 101,  22,  81,  93, 104,  82, 150, 158,  40,  36,
#         96,  13,  89,  83, 116,  18, 102,   3, 172,  44,  98,  37, 157,
#        160,  57, 112,  92,   6,   1,  19,  84, 167,  39,  95,  16, 103,
#        169,  88,  85,   2, 162,  10,   0,  29,  41,  12,   5,  34, 171,
#         38, 170, 156,  30, 115,  47,  21,  43,  14,   4, 118, 173,  99,
#        166,  11, 153,  42,   9, 165, 106,   8,  56,  35,  46, 144,  91,
#        164, 134, 168, 100,  76,  97,  87,  94, 122,  80, 143,   7,  20,
#         45, 131,  15, 120, 161, 163, 110,  62,  86,  90,  61, 141,  66,
#        121, 105, 152,  79, 154, 146,  73,  64,  54, 142,  49, 148,  65,
#         70, 109,  32,  71, 111, 139,  53, 129,  59, 138,  28,  77, 149,
#         31,  52, 132, 125,  50, 108, 147,  60,  25,  63,  55, 136, 124,
#        155,  69, 135, 128, 145,  33, 107,  23,  74, 126, 113,  27,  48,
#         78, 133, 127, 117,  51,  75, 140,  68, 151,  72, 119, 123, 114,
#         67,  26, 137,  58,  24])

# %%
data
# Out:
#       Age  Gender  Education Level  Job Title  Years of Experience    Salary
# 0    32.0       1                0        159                  5.0   90000.0
# 1    28.0       0                1         17                  3.0   65000.0
# 2    45.0       1                2        130                 15.0  150000.0
# 3    36.0       0                0        101                  7.0   60000.0
# 4    52.0       1                1         22                 20.0  200000.0
# ..    ...     ...              ...        ...                  ...       ...
# 370  35.0       0                0        131                  8.0   85000.0
# 371  43.0       1                1         30                 19.0  170000.0
# 372  29.0       0                0         70                  2.0   40000.0
# 373  34.0       1                0        137                  7.0   90000.0
# 374  44.0       0                2        110                 15.0  150000.0
#
# [373 rows x 6 columns]

# %%
x = data.drop("Salary",axis=1)

y = data["Salary"]

# %%
x.head()
# Out:
#     Age  Gender  Education Level  Job Title  Years of Experience
# 0  32.0       1                0        159                  5.0
# 1  28.0       0                1         17                  3.0
# 2  45.0       1                2        130                 15.0
# 3  36.0       0                0        101                  7.0
# 4  52.0       1                1         22                 20.0

# %%
y.head()
# Out:
# 0     90000.0
# 1     65000.0
# 2    150000.0
# 3     60000.0
# 4    200000.0
# Name: Salary, dtype: float64

# %%
model = LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([ 2652.29501743,  8322.28165554, 13290.95033734,    27.3298712 ,
#         3156.92278531])

# %%
model.predict([[3, 5, 2, 5, 16]])
# Out:
# C:\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([82515.21781381])

# %%
import seaborn as sns
sns.regplot(x="Age",
           y = "Salary",
           data = data[:200])
# Out:
# <Axes: xlabel='Age', ylabel='Salary'>

# %%
# split the data into testing and training

from sklearn.model_selection import train_test_split

# %%
xtrain, xtest, ytrain , ytest = train_test_split(data.drop("Salary",axis=1),data["Salary"], train_size = .75)

# %%
xtrain.shape
# Out:
# (279, 5)

# %%
model = LinearRegression()

# %%
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(xtest)

# %%
ytest.head(10)
# Out:
# 69     150000.0
# 27      40000.0
# 34     170000.0
# 127    110000.0
# 279    180000.0
# 320    160000.0
# 188    180000.0
# 44     130000.0
# 224     40000.0
# 108    100000.0
# Name: Salary, dtype: float64

# %%
xtest.head(10)
# Out:
#       Age  Gender  Education Level  Job Title  Years of Experience
# 69   49.0       0                1        118                 18.0
# 27   24.0       1                0         57                  1.0
# 34   46.0       1                2        130                 20.0
# 127  45.0       1                0        105                 18.0
# 279  49.0       0                1         30                 21.0
# 320  45.0       0                1        134                 16.0
# 188  50.0       0                2         33                 22.0
# 44   41.0       1                1        162                 13.0
# 224  28.0       1                0         59                  2.0
# 108  41.0       0                1        131                 14.0

# %%
for i in y_pred[:10]:
    print(i)
# Out:
# 157881.67553357768
# 34288.81014434926
# 179495.26269958005
# 145856.51894886198
# 165082.89425248938
# 142149.05094542896
# 182654.16504065244
# 132515.5762470215
# 47151.46358438031
# 125629.21459894539

# %%
model.score(xtrain, ytrain )
# Out:
# 0.9036517527069471

# %%
plt.scatter(xtest["Job Title"][:100],ytest[:100])
plt.plot(y_pred[:100])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error

# %%
mean_absolute_error(ytest, y_pred)
# Out:
# 13210.710792972775

# %%
mean_squared_error(ytest, y_pred)
# Out:
# 293111912.63890016

# %%
model.score(xtrain,ytrain)
# Out:
# 0.9036517527069471
